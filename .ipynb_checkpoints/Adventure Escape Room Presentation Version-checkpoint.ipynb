# %%
###Adventure Halloween Escape Room

# %%
room_data = {
    "game room": {
        "description": "Welcome to the Spooky House Escape Room Game, a piano and a locked Door A.",
        "puzzle":"What should I do?",
        "items": [{"piano": "key_A"}, "couch"],
        "doors": {"Door A": "locked"}
    },
     "bedroom 1" : {
        "description": "You are in Bedroom 1. You see a queen bed, Door B and Door C.",
        "items": ["queen bed", "key_B"],
        "doors": {"Door B": "locked", "Door C": "locked"}
    },
    "bedroom 2": {
        "description": "You're in Bedroom 2. You see a double bed, a dresser, and Door B.",
        "objects": ["double bed", "key_C", "dresser", "key_D"],
        "doors": {"Door B": "unlocked"}
    },
    "living room": {
        "description": "You're in the living room. You see a dining table, Door C, and Door D.",
        "objects": ["dining_table"],
        "doors": {"Door D": "locked"}
    },
    "outside": {
        "description": "You've stepped outside! Congratulations, you have escaped!",
        "objects": {},
        "doors": {}
            }
}

# %%
# Initialize inventory for the game
inventory = {"keys": [], "name": None, "play": True}

def start_game():
    """Function to start the game and transition to the game room."""
    print("Welcome to the Adventure Game!")
    print("You find yourself waking up in an unfamiliar room... The air feels heavy, and a strange silence fills the space.")
    print("Your mission is to find keys and solve puzzles to escape the rooms. Let's begin.")
    gameroom()

def gameroom():
    """Function for the game room."""
    print("\nLet the game begin!")
    name = input("What is your name, stranger? ")
    inventory["name"] = name  # Store name directly in the inventory dictionary
    print(f"As your eyes adjust, {name}, you see a grand piano, an old couch, and a door marked 'Door A' with a large lock.")

    while inventory["play"]:
        print("\nWhat would you like to do?")
        print("1 - Search for the key")
        print("2 - Exit")
       
        action = int(input("Choose an action (1 or 2): "))

        if action == 1:
            explore_game_room()
            break
        elif action == 2:
            print("An overwhelming sense of dread fills you as you quit the game.")
            inventory["play"] = False
        else:
            print("Invalid action. Try again.")

def explore_game_room():
    """Function to explore the game room."""
    while True:
        print("\nWhere would you like to search?")
        print("1 - Piano")
        print("2 - Couch")

        choice = int(input("Choose an option (1 or 2): "))

        if choice == 1:
            if "key_A" not in inventory['keys']:
                inventory['keys'].append("key_A")
                print("As you lift the piano lid, you find a small, old-fashioned treasure key lying there. It looks like it might open Door A!\n")
                puzzle_gameroom()
                break            
            else:
                print("You've already searched here. The piano holds no more secrets.")
                break
        elif choice == 2:
            print("You lift the cushions, but find nothing but dust. Hahaha!")
        else:
            print("Invalid choice. Please try again.")

    print("Keys in your inventory:", inventory['keys'])

def puzzle_gameroom():
    print("Decipher the puzzle to unlock Door A")
    while True:
        print("1 - String")
        print("2 - Integer")
        print("3 - Boolean")

        puzzle_answer = input("\nTrue or False represent which type of data in Python? Choose an option (1, 2, or 3): ")

        if puzzle_answer == "3":
            print("\nWell done! You have collected the treasure key.")
            break
        else:
            print("Wrong answer, please try again.")  # Loop repeats for wrong answers

    while True:
        next_action = input("Would you like to use that treasure key to unlock Door A? (1 - Yes, 2 - No): ")
        if next_action == "1":
            bedroom1()
            break
        elif next_action == "2":
            explore_game_room()
        else:
            print("Invalid choice. Please enter '1' or '2'.")

def bedroom1():
    """Function for Bedroom 1."""
    print("\nYou step through Door A, finding yourself in another dark room.")
    name = inventory["name"]
    print(f"\nCongratulations, {name}! You've moved up to Bedroom 1.")

    print("In this room, you see a grand, old queen bed against one wall, its heavy blankets untouched for years. Two doors stand ahead—Door B and Door C, each locked and silent.")
     
    while True:
        print("\nWhat would you like to do?")
        print("1 - Search for the key")
        print("2 - Exit")
        
        action = int(input("Choose an action (1 or 2): "))

        if action == 1:
            explore_bedroom1()
        elif action == 2:
            print("You decide to exit the game.")
            return
        else:
            print("Invalid action. Please try again.")

def explore_bedroom1():
    """Function to explore Bedroom 1."""
    while True:
        print("\nWould you like to search the queen bed or explore the room?")
        print("1 - Queen bed")
        print("2 - Explore the room")

        choice = int(input("Choose an option (1 or 2): "))
           
        if choice == 1:
            if "key_B" not in inventory['keys']:
                inventory['keys'].append("key_B")
                print("You lift the dusty blankets and feel around, finally grasping something cold — a key! The tag reads 'Door B!'")
                puzzle_bedroom_1()
                choose_door_bedroom1()
            else:
                print("The bed offers no more secrets; you’ve already claimed its hidden treasure.")
       
        elif choice == 2:
            print("You scan the room, but shadows hold their secrets closely.")
        else:
            print("Invalid choice. Please choose an option (1 or 2).")

    print("Keys in your inventory:", inventory['keys'])

def puzzle_bedroom_1():
    print("\nDecipher the puzzle to unlock Door B")
    while True:
        print("1 - #")
        print("2 - //")
        print("3 - /*")

        puzzle_answer = input("\nWhat symbol is used to start a comment in Python? Choose an option (1, 2, or 3): ")

        if puzzle_answer == "1":
            print("\nWell done! You’ve just claimed the hidden treasure key to unlock Door B.")
            return 1
        else:
            print("Wrong answer, please try again.")  # Loop repeats for wrong answers

def choose_door_bedroom1():
    """Function to choose which door to unlock in Bedroom 1."""
    while True:
        print("\nTry one of the doors")
        print("1 - Door B")
        print("2 - Door C")

        door_choice = int(input("Choose an option (1 or 2): "))
       
        if door_choice == 1:
            print("You insert the key into Door B, hearing a faint click as it opens...")
            bedroom2()
            break
        elif door_choice == 2:
            print("Sorry, Door C is locked tight, and something tells you this key won’t open it.")
        else:
            print("Invalid choice. Please choose 'Door B' or 'Door C'.")

def bedroom2():
    """Function for Bedroom 2."""
    name = inventory["name"]
    print(f"\nYou've entered Bedroom 2, where a double bed looms in the corner and a dresser stands against a wall stained with blood.")
    print("The air feels thick, and you sense more secrets here. You know that somewhere, there are keys that will lead you closer to freedom.")

    while True:
        print("\nWhat would you like to do?")
        print("1 - Search for keys")
        print("2 - Exit")
        
        action = int(input("Choose an action (1 or 2): "))

        if action == 1:
            explore_bedroom2()
            bedroom1_return()
        elif action == 2:
            print("An overwhelming sense of dread fills you as you quit the game.")
            return
        else:
            print("Invalid action. Try again.")

def explore_bedroom2():
    """Function to explore Bedroom 2."""
    i = 0
    while i < 2:
        print("\nWhere would you like to search?")
        print("1 - Double bed")
        print("2 - Dresser")

        choice = int(input("Choose an option (1 or 2): "))
        
        if choice == 1:
            if "key_C" not in inventory['keys']:
                inventory['keys'].append("key_C")
                i += 1
                print("Hidden between the sheets, you find a delicate, old-fashioned key marked 'Door C!'")
            else:
                print("The bed holds no more secrets. You’ve claimed one more treasure key.")
        elif choice == 2:
            if "key_D" not in inventory['keys']:
                inventory['keys'].append("key_D")
                i += 1
                print("You search the dresser and find another key marked 'Door D!'")
            else:
                print("The dresser offers no more secrets. You’ve already claimed its hidden treasure.")
        else:
            print("Invalid choice. Please try again.")
    print("Keys in your inventory:", inventory['keys'])

def bedroom1_return():
    """Function for returning to Bedroom 1 and solving the puzzle for Door C."""
    print("\nYou retrace your steps to Bedroom 1. With Key C in hand, Door C seems to call out to you.")
    while inventory["play"]==True:
        action = input("Would you like to open the door C?(yes/no)?").lower()
        if action == "yes":
            print("With a satisfying turn of the key, Door C swings open, revealing a living room ahead...")
            print("You have entered the final living room. Well done!")
            living_room()
            return True
        elif action == "no":
            print("You hesitate, but the feeling of urgency builds.")
            bedroom1_return()
        else:
            print("Invalid action. Try again.")

def living_room():
    """Function for the living room."""
    name = inventory["name"]
    print("\nYou step into the living room, where a dining table and Door D await.")
    print("What would you like to do?")
    print("1 - Open Door D")
    print("2 - Explore the dining table")

    action = input("Choose an option (1 or 2): ")

    if action == "2":
        print("We apologize, but the restaurant is closed! Try again tomorrow!")
        living_room()
    elif action == "1":
        if puzzle_livingroom() == 1:
            print("With a deep breath, you place the final key in the lock of Door D. The door creaks open, and fresh air rushes in.")
            print("\nCongratulations! You have escaped the eerie Adventure Room!")
            end_game()  # End the game immediately after opening Door D
    else:
        print("Invalid choice. Please choose '1' or '2'.")

def puzzle_livingroom():
    print("\nDecipher the puzzle to unlock Door D")
    while True:
        print("1 - Tuple")
        print("2 - List")
        print("3 - Dictionary")

        puzzle_answer = input("\nWhat is the mutable data structure that allows you to store key-value pairs? Choose an option (1, 2, or 3): ")

        if puzzle_answer == "3":
            print("\nWell done! You’ve just claimed the hidden treasure key to unlock Door D.")
            return 1
        else:
            print("Wrong answer, please try again.")  # Loop repeats for wrong answers

def end_game():
    """Function to end the game with a Halloween message."""
    print("\nAs you step into the night, a chilling wind whispers through the trees...")
    print("A haunting voice echoes behind you: 'The shadows will be waiting for your return... next Halloween.'")
    print("Thank you for playing, brave soul. Happy Halloween! 🎃👻")
    inventory["play"] = False  # Set play to False to mark the end of the game
    

# Start the game
start_game()
# Out:
# Welcome to the Adventure Game!
# You find yourself waking up in an unfamiliar room... The air feels heavy, and a strange silence fills the space.
# Your mission is to find keys and solve puzzles to escape the rooms. Let's begin.
#
# Let the game begin!
# As your eyes adjust, Cledenir, you see a grand piano, an old couch, and a door marked 'Door A' with a large lock.
#
# What would you like to do?
# 1 - Search for the key
# 2 - Exit
#
# Where would you like to search?
# 1 - Piano
# 2 - Couch
# As you lift the piano lid, you find a small, old-fashioned treasure key lying there. It looks like it might open Door A!
#
# Decipher the puzzle to unlock Door A
# 1 - String
# 2 - Integer
# 3 - Boolean
#
# Well done! You have collected the treasure key.
#
# You step through Door A, finding yourself in another dark room.
#
# Congratulations, Cledenir! You've moved up to Bedroom 1.
# In this room, you see a grand, old queen bed against one wall, its heavy blankets untouched for years. Two doors stand ahead—Door B and Door C, each locked and silent.
#
# What would you like to do?
# 1 - Search for the key
# 2 - Exit
#
# Would you like to search the queen bed or explore the room?
# 1 - Queen bed
# 2 - Explore the room
# You lift the dusty blankets and feel around, finally grasping something cold — a key! The tag reads 'Door B!'
#
# Decipher the puzzle to unlock Door B
# 1 - #
# 2 - //
# 3 - /*
#
# Well done! You’ve just claimed the hidden treasure key to unlock Door B.
#
# Try one of the doors
# 1 - Door B
# 2 - Door C
# You insert the key into Door B, hearing a faint click as it opens...
#
# You've entered Bedroom 2, where a double bed looms in the corner and a dresser stands against a wall stained with blood.
# The air feels thick, and you sense more secrets here. You know that somewhere, there are keys that will lead you closer to freedom.
#
# What would you like to do?
# 1 - Search for keys
# 2 - Exit
#
# Where would you like to search?
# 1 - Double bed
# 2 - Dresser
# Hidden between the sheets, you find a delicate, old-fashioned key marked 'Door C!'
#
# Where would you like to search?
# 1 - Double bed
# 2 - Dresser
# The bed holds no more secrets. You’ve claimed one more treasure key.
#
# Where would you like to search?
# 1 - Double bed
# 2 - Dresser
# You search the dresser and find another key marked 'Door D!'
# Keys in your inventory: ['key_A', 'key_B', 'key_C', 'key_D']
#
# You retrace your steps to Bedroom 1. With Key C in hand, Door C seems to call out to you.
# With a satisfying turn of the key, Door C swings open, revealing a living room ahead...
# You have entered the final living room. Well done!
#
# You step into the living room, where a dining table and Door D await.
# What would you like to do?
# 1 - Open Door D
# 2 - Explore the dining table
#
# Decipher the puzzle to unlock Door D
# 1 - Tuple
# 2 - List
# 3 - Dictionary
# Wrong answer, please try again.
# 1 - Tuple
# 2 - List
# 3 - Dictionary
# Wrong answer, please try again.
# 1 - Tuple
# 2 - List
# 3 - Dictionary
# Wrong answer, please try again.
# 1 - Tuple
# 2 - List
# 3 - Dictionary
# Wrong answer, please try again.
# 1 - Tuple
# 2 - List
# 3 - Dictionary
# Wrong answer, please try again.
# 1 - Tuple
# 2 - List
# 3 - Dictionary
#
# Well done! You’ve just claimed the hidden treasure key to unlock Door D.
# With a deep breath, you place the final key in the lock of Door D. The door creaks open, and fresh air rushes in.
#
# Congratulations! You have escaped the eerie Adventure Room!
#
# As you step into the night, a chilling wind whispers through the trees...
# A haunting voice echoes behind you: 'The shadows will be waiting for your return... next Halloween.'
# Thank you for playing, brave soul. Happy Halloween! 🎃👻
#
# What would you like to do?
# 1 - Search for keys
# 2 - Exit
#
# Where would you like to search?
# 1 - Double bed
# 2 - Dresser
# The bed holds no more secrets. You’ve claimed one more treasure key.
#
# Where would you like to search?
# 1 - Double bed
# 2 - Dresser
# The bed holds no more secrets. You’ve claimed one more treasure key.
#
# Where would you like to search?
# 1 - Double bed
# 2 - Dresser
# The dresser offers no more secrets. You’ve already claimed its hidden treasure.
#
# Where would you like to search?
# 1 - Double bed
# 2 - Dresser
# The bed holds no more secrets. You’ve claimed one more treasure key.
#
# Where would you like to search?
# 1 - Double bed
# 2 - Dresser
# The dresser offers no more secrets. You’ve already claimed its hidden treasure.
#
# Where would you like to search?
# 1 - Double bed
# 2 - Dresser
# The dresser offers no more secrets. You’ve already claimed its hidden treasure.
#
# Where would you like to search?
# 1 - Double bed
# 2 - Dresser
